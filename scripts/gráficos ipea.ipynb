# %%
import ipeadatapy as idpy   #pacote para utilizar API do Ipea Data que captura as séries temporais
import matplotlib.pyplot as plt
import matplotlib

# %%
idpy.list_series('IPCA')
# Out:
#                     CODE                                               NAME
# 4554       BM12_IPCA2012  IPCA - núcleo médias aparadas com suavização -...
# 4555      BM12_IPCA20N12  IPCA -  núcleo médias aparadas sem suavização ...
# 4556      BM12_IPCACOM12  IPCA - preços livres - comercializáveis - taxa...
# 4557      BM12_IPCAEXC12  IPCA - núcleo por exclusão - sem monitorados e...
# 4558   BM12_IPCAEXCEX212  IPCA - núcleo por exclusão - EX1 - taxa de var...
# 4559    BM12_IPCAEXP1212  Expectativa média de Inflação - IPCA - taxa ac...
# 4560     BM12_IPCAEXP612  Expectativa média de Inflação - IPCA - taxa an...
# 4561     BM12_IPCANCOM12  IPCA - preços livres - não comercializáveis - ...
# 4562       BM12_IPCAPL12            IPCA - preços livres - taxa de variação
# 4563     BM12_IPCAPLBD12  IPCA - preços livres - bens duráveis - taxa de...
# 4564    BM12_IPCAPLBND12  IPCA - preços livres - bens não duráveis - tax...
# ...

# %%
ipca = idpy.timeseries('PRECOS12_IPCA12')

# %%
ipca.head()
# Out:
#             YEAR  DAY  MONTH             CODE                   RAW DATE  \
# DATE
# 1979-12-01  1979    1     12  PRECOS12_IPCA12  1979-12-01T00:00:00-02:00
# 1980-01-01  1980    1      1  PRECOS12_IPCA12  1980-01-01T00:00:00-02:00
# 1980-02-01  1980    1      2  PRECOS12_IPCA12  1980-02-01T00:00:00-02:00
# 1980-03-01  1980    1      3  PRECOS12_IPCA12  1980-03-01T00:00:00-03:00
# 1980-04-01  1980    1      4  PRECOS12_IPCA12  1980-04-01T00:00:00-03:00
#
#                VALUE (-)
# DATE
# 1979-12-01  7.618300e-09
# 1980-01-01  8.122300e-09
# 1980-02-01  8.497300e-09
# 1980-03-01  9.010400e-09
# 1980-04-01  9.486700e-09

# %%
for  i in range(len(ipca)-12, len(ipca)-1):
    print(ipca.iloc[i:,5])
# Out:
# DATE
# 2021-02-01    5622.43
# 2021-03-01    5674.72
# 2021-04-01    5692.31
# 2021-05-01    5739.56
# 2021-06-01    5769.98
# 2021-07-01    5825.37
# 2021-08-01    5876.05
# 2021-09-01    5944.21
# 2021-10-01    6018.51
# 2021-11-01    6075.69
# 2021-12-01    6120.04
# 2022-01-01    6153.09
# Name: VALUE (-), dtype: float64
# DATE
# 2021-03-01    5674.72
# 2021-04-01    5692.31
# 2021-05-01    5739.56
# 2021-06-01    5769.98
# 2021-07-01    5825.37
# 2021-08-01    5876.05
# 2021-09-01    5944.21
# 2021-10-01    6018.51
# 2021-11-01    6075.69
# 2021-12-01    6120.04
# 2022-01-01    6153.09
# Name: VALUE (-), dtype: float64
# DATE
# 2021-04-01    5692.31
# 2021-05-01    5739.56
# 2021-06-01    5769.98
# 2021-07-01    5825.37
# 2021-08-01    5876.05
# 2021-09-01    5944.21
# 2021-10-01    6018.51
# 2021-11-01    6075.69
# 2021-12-01    6120.04
# 2022-01-01    6153.09
# Name: VALUE (-), dtype: float64
# DATE
# 2021-05-01    5739.56
# 2021-06-01    5769.98
# 2021-07-01    5825.37
# ...
