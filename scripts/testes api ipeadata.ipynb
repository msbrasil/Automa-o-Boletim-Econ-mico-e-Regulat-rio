# %% [markdown]
# # Automação Boletim Econômicos e Regulatório

# %%
import ipeadatapy as idpy

# %% [markdown]
# Função para buscar séries temporais

# %%
idpy.list_series('INPC')
# Out:
#                     CODE                                               NAME
# 4016  GAC12_TCERMTINPC12  Taxa de câmbio - efetiva real - INPC - importa...
# 4024  GAC12_TCERXMINPC12  Taxa de câmbio - efetiva real - INPC - exporta...
# 4027  GAC12_TCERXTINPC12  Taxa de câmbio - efetiva real - INPC - exporta...
# 4754     GAMMA_DEFLCENSO  Deflator para rendimentos do Censo Demográfico...
# 4755      GAMMA_DEFLPNAD            Deflator para rendimentos da PNAD: INPC
# 4756   GAMMA12_DEFLPME12             Deflator para rendimentos da PME: INPC
# 4928                INPC   INPC - Índice Nacional de  Preços ao  Consumidor
# 4984       PRECOS_INPCBR                            INPC - taxa de variação
# 4986     PRECOS12_INPC12            INPC - geral - índice (dez. 1993 = 100)
# 4987   PRECOS12_INPCAB12      INPC - alimentos e bebidas - taxa de variação
# 4988   PRECOS12_INPCAR12    INPC - artigos de residência - taxa de variação
# ...

# %% [markdown]
# Função que descreve os detalhes da série temporal

# %%
idpy.describe('PRECOS12_IPCA12')
# Out:
#                           IPCA - geral - índice (dez. 1993 = 100)
# Name                      IPCA - geral - índice (dez. 1993 = 100)
# Code                                              PRECOS12_IPCA12
# Big Theme                                          Macroeconômico
# Theme                                                      Preços
# Source          Instituto Brasileiro de Geografia e Estatístic...
# Source acronym                                         IBGE/SNIPC
# Comment         O Índice Nacional de Preços ao Consumidor Ampl...
# Last update                         2022-02-14T15:26:00.477-03:00
# Frequency                                                  Mensal
# Measure                                                         -
# Unit                                                         None
# Status                                                          A

# %% [markdown]
# função que traz a série temporal

# %%
ipca = idpy.timeseries('PRECOS12_IPCA12')[-12:]

# %%
ipca.iloc[-12:,5:].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
idpy.timeseries('PRECOS12_INPC12').tail()
# Out:
#             YEAR  DAY  MONTH             CODE                   RAW DATE  \
# DATE
# 2021-09-01  2021    1      9  PRECOS12_INPC12  2021-09-01T00:00:00-03:00
# 2021-10-01  2021    1     10  PRECOS12_INPC12  2021-10-01T00:00:00-03:00
# 2021-11-01  2021    1     11  PRECOS12_INPC12  2021-11-01T00:00:00-03:00
# 2021-12-01  2021    1     12  PRECOS12_INPC12  2021-12-01T00:00:00-03:00
# 2022-01-01  2022    1      1  PRECOS12_INPC12  2022-01-01T00:00:00-03:00
#
#             VALUE (-)
# DATE
# 2021-09-01    6160.89
# 2021-10-01    6232.36
# 2021-11-01    6284.71
# 2021-12-01    6330.59
# 2022-01-01    6373.00
